# %%
import json
import urllib.request as url

# %%
res = url.urlopen("https://api.covid19india.org/states_daily.json")

# %%
res

# %%
data = json.load(res)

# %%
type(data)
# Out:
# dict

# %%
data.keys()
# Out:
# dict_keys(['states_daily'])

# %%
data = data['states_daily']

# %%
type(data)
# Out:
# list

# %%
# data[0]

# %%
import pandas as pd

# %%
df = pd.DataFrame(data)

# %%
df.shape
# Out:
# (411, 41)

# %%
df.columns
# Out:
# Index(['an', 'ap', 'ar', 'as', 'br', 'ch', 'ct', 'date', 'dd', 'dl', 'dn',
#        'ga', 'gj', 'hp', 'hr', 'jh', 'jk', 'ka', 'kl', 'la', 'ld', 'mh', 'ml',
#        'mn', 'mp', 'mz', 'nl', 'or', 'pb', 'py', 'rj', 'sk', 'status', 'tg',
#        'tn', 'tr', 'tt', 'un', 'up', 'ut', 'wb'],
#       dtype='object')

# %%
df.head()
# Out:
#   an ap ar as br ch ct       date dd dl  ... sk     status tg tn tr  tt un  \
# 0  0  1  0  0  0  0  0  14-Mar-20  0  7  ...  0  Confirmed  1  1  0  81  0
# 1  0  0  0  0  0  0  0  14-Mar-20  0  1  ...  0  Recovered  0  0  0   9  0
# 2  0  0  0  0  0  0  0  14-Mar-20  0  1  ...  0   Deceased  0  0  0   2  0
# 3  0  0  0  0  0  0  0  15-Mar-20  0  0  ...  0  Confirmed  2  0  0  27  0
# 4  0  0  0  0  0  0  0  15-Mar-20  0  1  ...  0  Recovered  1  0  0   4  0
#
#    up ut wb
# 0  12  0  0
# 1   4  0  0
# 2   0  0  0
# 3   1  0  0
# 4   0  0  0
#
# [5 rows x 41 columns]

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
confirmed_df = df[df['status'] == 'Confirmed']

# %%
import matplotlib.pyplot as plt

# %%
df['dl'][0]
# Out:
# '7'

# %%
df['dl'] = df['dl'].astype('int32')

# %%
df['dl'][0]
# Out:
# 7

# %%
plt.scatter(confirmed_df['date'], confirmed_df['dl'])
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(confirmed_df['date'], confirmed_df['dl'])
plt.xticks(rotation='vertical')
plt.title("Confirmed cases in delhi")
plt.show()

# %%
df['up'] = df['up'].astype('int32')
confirmed_df = df[df['status'] == 'Confirmed']

# %%
plt.figure(figsize=(10,6))
plt.plot(confirmed_df['date'], confirmed_df['up'])
plt.xticks(rotation='vertical')
plt.title("Confirmed cases in UP")
plt.show()

# %%
plt.figure(figsize=(20,6))
plt.plot(confirmed_df['date'], confirmed_df['dl'],label='Delhi')
plt.plot(confirmed_df['date'], confirmed_df['up'],label='UP')
plt.xticks(rotation='vertical')
plt.title("Confirmed cases in Delhi vs UP")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.scatter(confirmed_df['date'], confirmed_df['up'])
plt.scatter(confirmed_df['date'], confirmed_df['dl'])
plt.xticks(rotation='vertical')
plt.title("Confirmed cases in UP")
plt.show()
